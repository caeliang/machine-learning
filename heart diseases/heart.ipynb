# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
X = heart_disease.data.features 
y = heart_disease.data.targets 

# metadata 
heart_disease.metadata
  
# variable information 
heart_disease.variables
# Out:
#         name     role         type demographic  \
# 0        age  Feature      Integer         Age
# 1        sex  Feature  Categorical         Sex
# 2         cp  Feature  Categorical        None
# 3   trestbps  Feature      Integer        None
# 4       chol  Feature      Integer        None
# 5        fbs  Feature  Categorical        None
# 6    restecg  Feature  Categorical        None
# 7    thalach  Feature      Integer        None
# 8      exang  Feature  Categorical        None
# 9    oldpeak  Feature      Integer        None
# 10     slope  Feature  Categorical        None
# 11        ca  Feature      Integer        None
# 12      thal  Feature  Categorical        None
# 13       num   Target      Integer        None
#
#                                           description  units missing_values
# 0                                                None  years             no
# 1                                                None   None             no
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()
model.add(Dense(13,activation='relu',input_shape=(13,)))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\ranim\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2969 - loss: -0.6671
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2006 - loss: 0.6858
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - accuracy: 0.1503 - loss: 0.6749
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.1690 - loss: 0.6663
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1687 - loss: 0.6582
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1886 - loss: 0.6409
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1941 - loss: 0.6201
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.1725 - loss: 0.6365
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1657 - loss: 0.6198
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - accuracy: 0.1937 - loss: 0.5992
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1792 - loss: 0.5895
# ...

# %%
import numpy as np

predictions = (model.predict(X) > 0.5).astype(int).flatten()
X_array = np.array(X)  # Convert DataFrame to NumPy array
y_array = np.array(y).flatten()
for i in range(5):
    print('%s => %d (expected %d)' % (X_array[i].tolist(), predictions[i], y_array[i]))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [63.0, 1.0, 1.0, 145.0, 233.0, 1.0, 2.0, 150.0, 0.0, 2.3, 3.0, 0.0, 6.0] => 1 (expected 0)
# [67.0, 1.0, 4.0, 160.0, 286.0, 0.0, 2.0, 108.0, 1.0, 1.5, 2.0, 3.0, 3.0] => 1 (expected 2)
# [67.0, 1.0, 4.0, 120.0, 229.0, 0.0, 2.0, 129.0, 1.0, 2.6, 2.0, 2.0, 7.0] => 1 (expected 1)
# [37.0, 1.0, 3.0, 130.0, 250.0, 0.0, 0.0, 187.0, 0.0, 3.5, 3.0, 0.0, 3.0] => 1 (expected 0)
# [41.0, 0.0, 2.0, 130.0, 204.0, 0.0, 2.0, 172.0, 0.0, 1.4, 1.0, 0.0, 3.0] => 1 (expected 0)

# %%
data=input('enter data to predict: ')
datanp=np.array(data.split(','),dtype=float)
print(model.predict(datanp.reshape(1,13)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# [[0.8752416]]
